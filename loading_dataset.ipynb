# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasShafiq/Power-BI-Dashboards/blob/main/loading_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlalchemy as db
from sqlalchemy import create_engine

# %%
cc = pd.read_excel('Data.xlsx', sheet_name='credit_card')
customer = pd.read_excel('Data.xlsx', sheet_name='customer')

# %%
cc.shape
# Out:
# (10108, 18)

# %%
customer.shape
# Out:
# (10108, 15)

# %%
cc.head()
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
# 3   708085458          Blue          250                   1
# 4   708086958          Blue          320                   1
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  Credit_Limit  \
# 0                 87      2023-01-01   Week-1  Q1          2023        3544.0
# 1                108      2023-01-01   Week-1  Q1          2023        3421.0
# 2                106      2023-01-01   Week-1  Q1          2023        8258.0
# 3                150      2023-01-01   Week-1  Q1          2023        1438.3
# 4                106      2023-01-01   Week-1  Q1          2023        3128.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# ...

# %%
engine = db.create_engine("postgresql+psycopg2://neondb_owner:npg_LcYSuem6nOG2@ep-billowing-haze-a1fl33c7-pooler.ap-southeast-1.aws.neon.tech/Database?sslmode=require")

# %%
customer.to_sql("Customers", con=engine, if_exists="replace", index=False)
cc.to_sql("cc", con=engine, if_exists="replace", index=False)
# Out:
# 108
